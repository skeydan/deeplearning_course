# %%
import numpy as np

# %%
x = np.array([1,2,3])
x
# Out:
# array([1, 2, 3])

# %%
x.shape
# Out:
# (3,)

# %%
x.reshape(3,1,1,1)
# Out:
# array([[[[1]]],
#
#
#        [[[2]]],
#
#
#        [[[3]]]])

# %%
x.reshape(3,1,1,1).shape
# Out:
# (3, 1, 1, 1)

# %%
np.dot?
